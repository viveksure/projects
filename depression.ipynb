# %%
import pandas as pd

# %%
df=pd.read_csv("depression.csv")

# %%
df
# Out:
#        Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0    Argentina  2018     13-15  Female                     50.3
# 1    Argentina  2018     13-15    Male                     44.9
# 2    Argentina  2018     16-17  Female                     67.2
# 3    Argentina  2018     16-17    Male                     68.1
# 4    Argentina  2012     13-15    Male                     49.3
# ..         ...   ...       ...     ...                      ...
# 139      india  2016     13-15  Female                      9.3
# 140      india  2016     16-17    Male                     27.5
# 141      india  2016     16-17  Female                     14.8
# 142      india  2015     13-15    Male                      6.1
# 143      india  2015     13-15  Female                      1.4
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 0                30.7        27.8            7.9                 16.8
# ...

# %%
df.head()
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 0              30.7        27.8            7.9                 16.8
# 1              26.1        39.1            8.4                 12.1
# 2              56.3        22.5           21.9                 28.5
# 3              55.8        27.9           27.0                 28.0
# 4              28.9        35.9           10.6                 17.0
#
#    Had_fights  No_close_friends  depression level
# 0        17.2               4.8                 0
# 1        33.2               5.5                 1
# ...

# %%
df.tail()
# Out:
#     Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 139   india  2016     13-15  Female                      9.3
# 140   india  2016     16-17    Male                     27.5
# 141   india  2016     16-17  Female                     14.8
# 142   india  2015     13-15    Male                      6.1
# 143   india  2015     13-15  Female                      1.4
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 139               4.5        27.4            2.5                  4.3
# 140              26.5        22.1           13.7                 22.3
# 141              11.8        36.9            4.2                 10.0
# 142               5.1        15.7            2.1                 21.5
# 143               0.8        14.9            0.7                  1.5
#
#      Had_fights  No_close_friends  depression level
# 139        24.2               6.6                 1
# 140        39.3               9.6                 1
# ...

# %%
df[45:]
# Out:
#       Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 45   Malaysia  2012     16-17  Female                      7.4
# 46   Mauritus  2017     13-15    Male                     20.2
# 47   Mauritus  2017     13-15  Female                     21.2
# 48   Mauritus  2017     16-17    Male                     40.1
# 49   Mauritus  2017     16-17  Female                     29.6
# ..        ...   ...       ...     ...                      ...
# 139     india  2016     13-15  Female                      9.3
# 140     india  2016     16-17    Male                     27.5
# 141     india  2016     16-17  Female                     14.8
# 142     india  2015     13-15    Male                      6.1
# 143     india  2015     13-15  Female                      1.4
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 45                5.8        11.2            0.3                  2.5
# ...

# %%
df[50:60]
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 50  Mongolia  2013     13-15    Male                      4.9
# 51  Mongolia  2013     13-15  Female                      3.9
# 52  Mongolia  2013     16-17    Male                     23.2
# 53  Mongolia  2013     16-17  Female                     13.0
# 54  Mongolia  2010     13-15    Male                      6.6
# 55  Mongolia  2010     13-15  Female                      4.5
# 56   Namibia  2013     13-15    Male                     26.4
# 57   Namibia  2013     13-15  Female                     21.4
# 58   Namibia  2013     16-17    Male                     42.2
# 59   Namibia  2013     16-17  Female                     34.9
#
#     Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 50               8.5        11.3            1.5                  8.3
# 51               4.7        11.7            0.9                  3.3
# 52              32.6         6.3            2.2                 26.9
# ...

# %%
df.loc[1:5]
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
# 5  Argentina  2012     13-15  Female                     50.7
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 1              26.1        39.1            8.4                 12.1
# 2              56.3        22.5           21.9                 28.5
# 3              55.8        27.9           27.0                 28.0
# 4              28.9        35.9           10.6                 17.0
# 5              26.8        21.8            6.5                 20.5
#
#    Had_fights  No_close_friends  depression level
# 1        33.2               5.5                 1
# 2        15.1               6.3                 2
# ...

# %%
df.loc[:20]
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# 5             Argentina  2012     13-15  Female                     50.7
# 6             Barabados  2011     13-15    Male                     29.4
# 7             Barabados  2011     13-15  Female                     26.6
# 8                 Benin  2016     13-15    Male                     38.0
# 9                 Benin  2016     13-15  Female                     42.4
# 10                Benin  2016     16-17    Male                     46.5
# 11                Benin  2016     16-17  Female                     36.1
# ...

# %%
df.loc[143,'Country']
# Out:
# 'india'

# %%
df.loc[3:16,['Country','Sex']]
# Out:
#                Country     Sex
# 3            Argentina    Male
# 4            Argentina    Male
# 5            Argentina  Female
# 6            Barabados    Male
# 7            Barabados  Female
# 8                Benin    Male
# 9                Benin  Female
# 10               Benin    Male
# 11               Benin  Female
# 12              Bhutan    Male
# 13              Bhutan  Female
# 14              Bhutan    Male
# 15              Bhutan  Female
# 16  Brunei Darussalam     Male

# %%
df.iloc[1:5,1:4]
# Out:
#    Year Age Group     Sex
# 1  2018     13-15    Male
# 2  2018     16-17  Female
# 3  2018     16-17    Male
# 4  2012     13-15    Male

# %%
df.iloc[:10,:6]
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
# 5  Argentina  2012     13-15  Female                     50.7
# 6  Barabados  2011     13-15    Male                     29.4
# 7  Barabados  2011     13-15  Female                     26.6
# 8      Benin  2016     13-15    Male                     38.0
# 9      Benin  2016     13-15  Female                     42.4
#
#    Really_Get_Drunk
# 0              30.7
# 1              26.1
# 2              56.3
# 3              55.8
# 4              28.9
# 5              26.8
# 6              80.2
# 7              78.0
# 8              19.3
# 9              16.8

# %%
df.iloc[[2,4,6,],[2,4,6]]
# Out:
#   Age Group  Currently_Drink_Alcohol  Overwieght
# 2     16-17                     67.2        22.5
# 4     13-15                     49.3        35.9
# 6     13-15                     29.4        32.3

# %%
df.shape
# Out:
# (144, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  144 non-null    object
#  1   Year                     144 non-null    int64
#  2   Age Group                144 non-null    object
#  3   Sex                      144 non-null    object
#  4   Currently_Drink_Alcohol  143 non-null    float64
#  5   Really_Get_Drunk         138 non-null    float64
#  6   Overwieght               143 non-null    float64
#  7   Use_Marijuana            143 non-null    float64
#  8   Smoke_cig_currently      140 non-null    float64
#  9   Had_fights               141 non-null    float64
#  10  No_close_friends         143 non-null    float64
#  11  depression level         144 non-null    int64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 13.6+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# Length: 144, dtype: bool

# %%
df.describe()
# Out:
#               Year  Currently_Drink_Alcohol  Really_Get_Drunk  Overwieght  \
# count   144.000000               143.000000        138.000000  143.000000
# mean   2014.708333                34.002098         22.769565   24.014685
# std       2.051351                63.771621         17.519852   16.018655
# min    2010.000000                 1.400000          0.800000    3.300000
# 25%    2013.000000                10.900000          8.900000   12.600000
# 50%    2015.000000                26.400000         19.650000   21.800000
# 75%    2016.000000                42.400000         30.475000   32.100000
# max    2018.000000               548.000000         80.200000   70.600000
#
#        Use_Marijuana  Smoke_cig_currently  Had_fights  No_close_friends  \
# count     143.000000           140.000000  141.000000        143.000000
# mean        7.499301            16.072857   32.173050          7.625175
# std         8.769092            11.211279   14.383636          4.263280
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.sample()
# Out:
#      Country  Year Age Group   Sex  Currently_Drink_Alcohol  Really_Get_Drunk  \
# 42  Malaysia  2012     13-15  Male                      9.3               6.8
#
#     Overwieght  Use_Marijuana  Smoke_cig_currently  Had_fights  \
# 42        25.3            1.4                 17.1        38.5
#
#     No_close_friends  depression level
# 42               3.6                 0

# %%
df.dtypes
# Out:
# Country                     object
# Year                         int64
# Age Group                   object
# Sex                         object
# Currently_Drink_Alcohol    float64
# Really_Get_Drunk           float64
# Overwieght                 float64
# Use_Marijuana              float64
# Smoke_cig_currently        float64
# Had_fights                 float64
# No_close_friends           float64
# depression level             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Age Group', 'Sex', 'Currently_Drink_Alcohol',
#        'Really_Get_Drunk', 'Overwieght', 'Use_Marijuana',
#        'Smoke_cig_currently', 'Had_fights', 'No_close_friends',
#        'depression level'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Country                    28
# Year                        9
# Age Group                   2
# Sex                         2
# Currently_Drink_Alcohol    94
# Really_Get_Drunk           89
# Overwieght                 90
# Use_Marijuana              81
# Smoke_cig_currently        92
# Had_fights                 96
# No_close_friends           68
# depression level            3
# dtype: int64

# %%
df.count()
# Out:
# Country                    144
# Year                       144
# Age Group                  144
# Sex                        144
# Currently_Drink_Alcohol    143
# Really_Get_Drunk           138
# Overwieght                 143
# Use_Marijuana              143
# Smoke_cig_currently        140
# Had_fights                 141
# No_close_friends           143
# depression level           144
# dtype: int64

# %%
df.corr()
# Out:
#                              Year  Currently_Drink_Alcohol  Really_Get_Drunk  \
# Year                     1.000000                 0.190991          0.020696
# Currently_Drink_Alcohol  0.190991                 1.000000          0.264792
# Really_Get_Drunk         0.020696                 0.264792          1.000000
# Overwieght               0.008439                 0.026514          0.252719
# Use_Marijuana            0.176630                 0.318662          0.565078
# Smoke_cig_currently     -0.024822                 0.113639          0.598968
# Had_fights              -0.202056                 0.090369          0.121192
# No_close_friends         0.129968                 0.123935          0.157679
# depression level        -0.109975                -0.114208          0.151670
#
#                          Overwieght  Use_Marijuana  Smoke_cig_currently  \
# Year                       0.008439       0.176630            -0.024822
# ...

# %%
df[df['Year']>2011]
# Out:
#        Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0    Argentina  2018     13-15  Female                     50.3
# 1    Argentina  2018     13-15    Male                     44.9
# 2    Argentina  2018     16-17  Female                     67.2
# 3    Argentina  2018     16-17    Male                     68.1
# 4    Argentina  2012     13-15    Male                     49.3
# ..         ...   ...       ...     ...                      ...
# 139      india  2016     13-15  Female                      9.3
# 140      india  2016     16-17    Male                     27.5
# 141      india  2016     16-17  Female                     14.8
# 142      india  2015     13-15    Male                      6.1
# 143      india  2015     13-15  Female                      1.4
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 0                30.7        27.8            7.9                 16.8
# ...

# %%
df[df['Year']>2011].loc[4:8]
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 4  Argentina  2012     13-15    Male                     49.3
# 5  Argentina  2012     13-15  Female                     50.7
# 8      Benin  2016     13-15    Male                     38.0
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 4              28.9        35.9           10.6                 17.0
# 5              26.8        21.8            6.5                 20.5
# 8              19.3        12.7            0.8                  5.1
#
#    Had_fights  No_close_friends  depression level
# 4        44.2               6.1                 0
# 5        24.7               4.3                 2
# 8        32.1              10.8                 2

# %%
df[df['Year']>2011].loc[4:8,['Year','depression level']]
# Out:
#    Year  depression level
# 4  2012                 0
# 5  2012                 2
# 8  2016                 2

# %%
df[df['Year']>2011].iloc[1:5,2:9]
# Out:
#   Age Group     Sex  Currently_Drink_Alcohol  Really_Get_Drunk  Overwieght  \
# 1     13-15    Male                     44.9              26.1        39.1
# 2     16-17  Female                     67.2              56.3        22.5
# 3     16-17    Male                     68.1              55.8        27.9
# 4     13-15    Male                     49.3              28.9        35.9
#
#    Use_Marijuana  Smoke_cig_currently
# 1            8.4                 12.1
# 2           21.9                 28.5
# 3           27.0                 28.0
# 4           10.6                 17.0

# %%
df.isna().sum()
# Out:
# Country                    0
# Year                       0
# Age Group                  0
# Sex                        0
# Currently_Drink_Alcohol    1
# Really_Get_Drunk           6
# Overwieght                 1
# Use_Marijuana              1
# Smoke_cig_currently        4
# Had_fights                 3
# No_close_friends           1
# depression level           0
# dtype: int64

# %%
df.columns[df.isna().any()]
# Out:
# Index(['Currently_Drink_Alcohol', 'Really_Get_Drunk', 'Overwieght',
#        'Use_Marijuana', 'Smoke_cig_currently', 'Had_fights',
#        'No_close_friends'],
#       dtype='object')

# %%
d=df.Currently_Drink_Alcohol.fillna(df.Currently_Drink_Alcohol.mean())

# %%
d.tail()
# Out:
# 139     9.3
# 140    27.5
# 141    14.8
# 142     6.1
# 143     1.4
# Name: Currently_Drink_Alcohol, dtype: float64

# %%
d1=df.Use_Marijuana.fillna(df.Use_Marijuana.median())

# %%
d1.tail()
# Out:
# 139     2.5
# 140    13.7
# 141     4.2
# 142     2.1
# 143     0.7
# Name: Use_Marijuana, dtype: float64

# %%
d3=df.fillna(0)

# %%
d3
# Out:
#        Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0    Argentina  2018     13-15  Female                     50.3
# 1    Argentina  2018     13-15    Male                     44.9
# 2    Argentina  2018     16-17  Female                     67.2
# 3    Argentina  2018     16-17    Male                     68.1
# 4    Argentina  2012     13-15    Male                     49.3
# ..         ...   ...       ...     ...                      ...
# 139      india  2016     13-15  Female                      9.3
# 140      india  2016     16-17    Male                     27.5
# 141      india  2016     16-17  Female                     14.8
# 142      india  2015     13-15    Male                      6.1
# 143      india  2015     13-15  Female                      1.4
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 0                30.7        27.8            7.9                 16.8
# ...

# %%
d3.isna().sum()
# Out:
# Country                    0
# Year                       0
# Age Group                  0
# Sex                        0
# Currently_Drink_Alcohol    0
# Really_Get_Drunk           0
# Overwieght                 0
# Use_Marijuana              0
# Smoke_cig_currently        0
# Had_fights                 0
# No_close_friends           0
# depression level           0
# dtype: int64

# %%
df1=d3.drop(['Really_Get_Drunk'],axis=1)

# %%
df1
# Out:
#        Country  Year Age Group     Sex  Currently_Drink_Alcohol  Overwieght  \
# 0    Argentina  2018     13-15  Female                     50.3        27.8
# 1    Argentina  2018     13-15    Male                     44.9        39.1
# 2    Argentina  2018     16-17  Female                     67.2        22.5
# 3    Argentina  2018     16-17    Male                     68.1        27.9
# 4    Argentina  2012     13-15    Male                     49.3        35.9
# ..         ...   ...       ...     ...                      ...         ...
# 139      india  2016     13-15  Female                      9.3        27.4
# 140      india  2016     16-17    Male                     27.5        22.1
# 141      india  2016     16-17  Female                     14.8        36.9
# 142      india  2015     13-15    Male                      6.1        15.7
# 143      india  2015     13-15  Female                      1.4        14.9
#
# ...

# %%
df2=df1.rename({'Sex':'Gender','Age Group':'Age','Currently_Drink_Alcohol':'Drink_Alcohol','Use_Marijuana':'drug'},axis=1)

# %%
df2
# Out:
#        Country  Year    Age  Gender  Drink_Alcohol  Overwieght  drug  \
# 0    Argentina  2018  13-15  Female           50.3        27.8   7.9
# 1    Argentina  2018  13-15    Male           44.9        39.1   8.4
# 2    Argentina  2018  16-17  Female           67.2        22.5  21.9
# 3    Argentina  2018  16-17    Male           68.1        27.9  27.0
# 4    Argentina  2012  13-15    Male           49.3        35.9  10.6
# ..         ...   ...    ...     ...            ...         ...   ...
# 139      india  2016  13-15  Female            9.3        27.4   2.5
# 140      india  2016  16-17    Male           27.5        22.1  13.7
# 141      india  2016  16-17  Female           14.8        36.9   4.2
# 142      india  2015  13-15    Male            6.1        15.7   2.1
# 143      india  2015  13-15  Female            1.4        14.9   0.7
#
#      Smoke_cig_currently  Had_fights  No_close_friends  depression level
# ...

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df2.head()
# Out:
#      Country  Year    Age  Gender  Drink_Alcohol  Overwieght  drug  \
# 0  Argentina  2018  13-15  Female           50.3        27.8   7.9
# 1  Argentina  2018  13-15    Male           44.9        39.1   8.4
# 2  Argentina  2018  16-17  Female           67.2        22.5  21.9
# 3  Argentina  2018  16-17    Male           68.1        27.9  27.0
# 4  Argentina  2012  13-15    Male           49.3        35.9  10.6
#
#    Smoke_cig_currently  Had_fights  No_close_friends  depression level
# 0                 16.8        17.2               4.8                 0
# 1                 12.1        33.2               5.5                 1
# 2                 28.5        15.1               6.3                 2
# 3                 28.0        33.6               6.6                 1
# 4                 17.0        44.2               6.1                 0

# %%
df2.columns
# Out:
# Index(['Country', 'Year', 'Age', 'Gender', 'Drink_Alcohol', 'Overwieght',
#        'drug', 'Smoke_cig_currently', 'Had_fights', 'No_close_friends',
#        'depression level'],
#       dtype='object')

# %%
print(df2.Gender.value_counts())
df2.Gender.value_counts().plot.bar()
# Out:
# Female    72
# Male      72
# Name: Gender, dtype: int64
# <AxesSubplot:>

# %%
df2.Age.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df2.Smoke_cig_currently.value_counts()
# Out:
# 1.5     5
# 0.0     4
# 4.3     4
# 9.7     3
# 21.5    3
#        ..
# 22.9    1
# 10.2    1
# 6.4     1
# 17.4    1
# 3.3     1
# Name: Smoke_cig_currently, Length: 93, dtype: int64

# %%
df2.Smoke_cig_currently.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#        Country  Year    Age  Gender  Drink_Alcohol  Overwieght  drug  \
# 0    Argentina  2018  13-15  Female           50.3        27.8   7.9
# 1    Argentina  2018  13-15    Male           44.9        39.1   8.4
# 2    Argentina  2018  16-17  Female           67.2        22.5  21.9
# 3    Argentina  2018  16-17    Male           68.1        27.9  27.0
# 4    Argentina  2012  13-15    Male           49.3        35.9  10.6
# ..         ...   ...    ...     ...            ...         ...   ...
# 139      india  2016  13-15  Female            9.3        27.4   2.5
# 140      india  2016  16-17    Male           27.5        22.1  13.7
# 141      india  2016  16-17  Female           14.8        36.9   4.2
# 142      india  2015  13-15    Male            6.1        15.7   2.1
# 143      india  2015  13-15  Female            1.4        14.9   0.7
#
#      Smoke_cig_currently  Had_fights  No_close_friends  depression level
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9,9))
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.bar(df2.Age,df2.Smoke_cig_currently)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.barplot(x='Gender',y='Smoke_cig_currently',data=df2,palette="Blues")
plt.title('Gender wise Analysis')
plt.xlabel("Gender")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
sns.barplot(x='Age',y='Smoke_cig_currently',hue='depression level',data=df2,palette="Blues")
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
df2.Age.hist()
# Out:
# <AxesSubplot:>

# %%
df2.hist(column='Age',by="depression level",bins =12)
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>, <AxesSubplot:>]], dtype=object)

# %%
plt.title('Drugs wise Analysis')
plt.xlabel("Use_Marijuana")
plt.ylabel("Smoke_cig_currently")
plt.scatter(df2.Gender,df2.Smoke_cig_currently)
plt.show()

# %%
sns.scatterplot(x='Age',y='Smoke_cig_currently',hue='depression level',data=df2,palette="Blues")
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
df2.Smoke_cig_currently.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.Smoke_cig_currently.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxenplot(x='Age',y='Smoke_cig_currently',hue='depression level',data=df2,palette="Blues")
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
sns.catplot(x='Age',y='Smoke_cig_currently',hue='depression level',data=df2,palette="Blues")
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
sns.heatmap(df2[['depression level','Smoke_cig_currently']])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df2.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df2.corr(),annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,export_text

# %%
df2
# Out:
#        Country  Year    Age  Gender  Drink_Alcohol  Overwieght  drug  \
# 0    Argentina  2018  13-15  Female           50.3        27.8   7.9
# 1    Argentina  2018  13-15    Male           44.9        39.1   8.4
# 2    Argentina  2018  16-17  Female           67.2        22.5  21.9
# 3    Argentina  2018  16-17    Male           68.1        27.9  27.0
# 4    Argentina  2012  13-15    Male           49.3        35.9  10.6
# ..         ...   ...    ...     ...            ...         ...   ...
# 139      india  2016  13-15  Female            9.3        27.4   2.5
# 140      india  2016  16-17    Male           27.5        22.1  13.7
# 141      india  2016  16-17  Female           14.8        36.9   4.2
# 142      india  2015  13-15    Male            6.1        15.7   2.1
# 143      india  2015  13-15  Female            1.4        14.9   0.7
#
#      Smoke_cig_currently  Had_fights  No_close_friends  depression level
# ...

# %%
#drop unrequired columns
df5=df2.drop(columns=['Country','Year','Age','Gender','Overwieght'])

# %%
df5
# Out:
#      Drink_Alcohol  drug  Smoke_cig_currently  Had_fights  No_close_friends  \
# 0             50.3   7.9                 16.8        17.2               4.8
# 1             44.9   8.4                 12.1        33.2               5.5
# 2             67.2  21.9                 28.5        15.1               6.3
# 3             68.1  27.0                 28.0        33.6               6.6
# 4             49.3  10.6                 17.0        44.2               6.1
# ..             ...   ...                  ...         ...               ...
# 139            9.3   2.5                  4.3        24.2               6.6
# 140           27.5  13.7                 22.3        39.3               9.6
# 141           14.8   4.2                 10.0        24.7               7.6
# 142            6.1   2.1                 21.5        35.9               3.8
# 143            1.4   0.7                  1.5        13.1               2.4
#
#      depression level
# 0                   0
# ...

# %%
x=df5.iloc[:,0:5]
y=df5['depression level']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

# %%
x_train.head()
# Out:
#      Drink_Alcohol  drug  Smoke_cig_currently  Had_fights  No_close_friends
# 123            3.2   0.0                  4.3        17.1               2.5
# 75            60.4  28.6                 21.2        14.9               7.3
# 13            11.7   3.6                  9.6        34.3              10.3
# 28             6.1   2.1                 21.5        35.9               3.8
# 129            6.1   2.1                 21.5        35.9               3.8

# %%
y_train.head()
# Out:
# 123    2
# 75     2
# 13     1
# 28     2
# 129    0
# Name: depression level, dtype: int64

# %%
model=DecisionTreeClassifier(random_state=0,max_depth=3)
s=model.fit(x_train,y_train)
s1=export_text(s)
print(s1)
pred=model.predict(x_test)
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))
# Out:
# |--- feature_3 <= 17.55
# |   |--- feature_1 <= 4.05
# |   |   |--- feature_3 <= 12.85
# |   |   |   |--- class: 1
# |   |   |--- feature_3 >  12.85
# |   |   |   |--- class: 0
# |   |--- feature_1 >  4.05
# |   |   |--- class: 2
# |--- feature_3 >  17.55
# |   |--- feature_4 <= 10.55
# |   |   |--- feature_2 <= 8.75
# |   |   |   |--- class: 2
# |   |   |--- feature_2 >  8.75
# |   |   |   |--- class: 1
# |   |--- feature_4 >  10.55
# |   |   |--- feature_4 <= 14.70
# |   |   |   |--- class: 0
# |   |   |--- feature_4 >  14.70
# |   |   |   |--- class: 1
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.31      0.42        29
#            1       0.33      0.59      0.42        22
#            2       0.33      0.29      0.31        21
#
#     accuracy                           0.39        72
#    macro avg       0.43      0.40      0.38        72
# weighted avg       0.46      0.39      0.39        72
#
# [[ 9 14  6]
#  [ 3 13  6]
# ...

# %%
from sklearn.metrics import accuracy_score
print("Accuracy: ",accuracy_score(y_test,pred)*100)
# Out:
# Accuracy:  38.88888888888889

# %%
Drink_Alcohol=float(input())
drug=float(input())
Smoke_cig_currently=float(input())
Had_fights=float(input())
No_close_friends=float(input())
df5={'Alcohol':[Drink_Alcohol],'drug':[drug],'Smoke':[Smoke_cig_currently],'fights':[Had_fights],'friends':[No_close_friends]}
df=pd.DataFrame(df5)
# Out:
# 23.7
# 34.2
# 43.8
# 12.9
# 32.9

# %%
df
# Out:
#    Alcohol  drug  Smoke  fights  friends
# 0     23.7  34.2   43.8    12.9     32.9

# %%
y_pred=model.predict(df)

# %%
y_pred
# Out:
# array([2], dtype=int64)
